# %%
# Najeeb Fariduddin Saiyed
# PRN 21070126057

# %% [markdown]
# ## Importing Libraries

# %%
import gym
import numpy as np
from IPython import display
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def test_env(env: gym.Env) -> None:
    env.reset() # resetting env so your back to initial state
    done = False
    img = plt.imshow(env.render(mode="rgb_array"))
    while not done:
        _, _, done, _ = env.step(env.action_space.sample())
        img.set_data(env.render(mode="rgb_array"))
        plt.axis("on")
        display.display(plt.gcf())
        display.clear_output(wait = True)

# %% [markdown]
# ##  CartPole: Keep the tip of the pole straight

# %%
env = gym.make("CartPole-v1")
test_env(env)
env.close()

# %% [markdown]
# ### Environment Observations

# %% [markdown]
# ![image.png](attachment:48a677b4-59c7-4326-a50c-32f45077937c.png)

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %% [markdown]
# Car position, cart velo, pole angle, pole angular velocity
#
# 0 for left movement
# 1 for right movement

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# ## Acrobat: Swing the bar up to a certain height

# %%
env = gym.make('Acrobot-v1')
test_env(env)
env.close()

# %% [markdown]
# ### Environment Observations

# %% [markdown]
# ![image.png](attachment:0f71bee4-5023-4fdc-868d-30af6b01490b.png)

# %%
env.observation_space
# Out:
# Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# ## MountainCar: Reach the goal from the bottom of the valley

# %%
env = gym.make('MountainCar-v0')
test_env(env)
env.close()

# %% [markdown]
# ### Environment Observations

# %% [markdown]
# ![image.png](attachment:ba0f1312-73ad-4822-96c0-568f14ede9af.png)

# %%
env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# ## Pendulum: swing it and keep it upright

# %%
env = gym.make('Pendulum-v1')
test_env(env)
env.close()

# %% [markdown]
# ### Environment Observations

# %% [markdown]
# ![image.png](attachment:e5b95101-bea5-4713-91a1-16accd7c8303.png)

# %%
env.observation_space
# Out:
# Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)

# %%
env.action_space
# Out:
# Box(-2.0, 2.0, (1,), float32)
